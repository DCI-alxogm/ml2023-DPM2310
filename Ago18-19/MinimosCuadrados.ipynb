# %% [markdown]
# <a href="https://colab.research.google.com/github/DCI-alxogm/ml2023-DPM2310/blob/main/Ago18-19/MinimosCuadrados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minimos Cuadrados

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Leemos los datos subiendo el dataset directamente a collaboratory
data=np.loadtxt("olympic100m_men.txt",delimiter=',').T

# %%
#Almacenamos fila de datos en listas distintas
x=data[0]
y=data[1]

# %%
#Graficamos la dispersion de los datos
plt.scatter(x,y)

# %% [markdown]
# Buscamos encontrar la pendiente y la ordenada al orgien para la recta que mejor describa los datos de la grafica anterior a travez del metodo de minimos cuadrados.

# %%
#Definimos los parametros necesarios para realizar el ajuste
N=len(x)
m=(N*sum(x*y)-sum(x)*sum(y))/(N*sum(x**2)-sum(x)**2)
b=(sum(y)-m*sum(x))/N

#Recta que mejor define los datos
f=m*x+b

#Graficamos
plt.plot(x,y,'o',label='(xi,yi)')
plt.plot(x,f,color='red',label='Ajuste Lineal')
plt.title('Minimos Cuadrados')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
print("m =",m)
print("b =",b)
# Out:
# m = -0.013330885710957176
# b = 36.41645590249617
